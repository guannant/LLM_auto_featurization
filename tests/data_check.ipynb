# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
# Prepare things to read

# Where datasets are stored
datasets_dir = Path.home() / "Box/LLM hackathon 2025 Featurizers/datasets"

# %% [markdown]
# Getting just the MPEA data.

# %%
mpea_path = datasets_dir / "MPEA/data.csv"

mpea = pd.read_csv(mpea_path)

mpea
# Out:
#       IDENTIFIER: Reference ID             FORMULA  \
# 0                           27  Al0.25 Co1 Fe1 Ni1
# 1                           27   Al0.5 Co1 Fe1 Ni1
# 2                           27  Al0.75 Co1 Fe1 Ni1
# 3                           27     Al1 Co1 Fe1 Ni1
# 4                           27         Co1 Fe1 Ni1
# ...                        ...                 ...
# 1540                       265     Hf1 Nb1 Ta1 Ti1
# 1541                       265  Mo1 Nb1 Ta1 Ti1 W1
# 1542                       265  Mo1 Nb1 Ta1 Ti1 W1
# 1543                       265     Mo1 Nb1 Ta1 Ti1
# 1544                       265     Mo1 Nb1 Ta1 Ti1
#
#      INPUT PROPERTY: Microstructure INPUT PROPERTY: Processing method  \
# 0                               FCC                              CAST
# 1                           FCC+BCC                              CAST
# 2                           FCC+BCC                              CAST
# 3                               BCC                              CAST
# 4                               FCC                              CAST
# ...                             ...                               ...
# 1540                            BCC                              CAST
# 1541                            BCC                            ANNEAL
# 1542                            BCC                              CAST
# 1543                            BCC                            ANNEAL
# 1544                            BCC                              CAST
#
#      INPUT PROPERTY: BCC/FCC/other  INPUT PROPERTY: grain size ($\mu$m)  \
# 0                              FCC                                  NaN
# 1                            other                                  NaN
# 2                            other                                  NaN
# 3                              BCC                                  NaN
# 4                              FCC                                  NaN
# ...                            ...                                  ...
# 1540                           BCC                                  NaN
# 1541                           BCC                                  NaN
# 1542                           BCC                                  NaN
# 1543                           BCC                                  NaN
# 1544                           BCC                                  NaN
#
#       INPUT PROPERTY: Exp. Density (g/cm$^3$)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1540                                      NaN
# 1541                                      NaN
# 1542                                      NaN
# 1543                                      NaN
# 1544                                      NaN
#
#       INPUT PROPERTY: Calculated Density (g/cm$^3$)  OUTPUT PROPERTY: HV  \
# 0                                               7.9                138.0
# 1                                               7.4                212.0
# 2                                               7.0                385.0
# 3                                               6.6                456.0
# 4                                               8.5                125.0
# ...                                             ...                  ...
# 1540                                           10.9                270.0
# 1541                                           11.8                482.0
# 1542                                           11.8                446.0
# 1543                                           10.0                407.0
# 1544                                           10.0                431.0
#
#      INPUT PROPERTY: Type of test  ...  OUTPUT PROPERTY: Elongation (%)  \
# 0                               C  ...                              NaN
# 1                               C  ...                              NaN
# 2                               C  ...                              NaN
# 3                               C  ...                              NaN
# 4                               C  ...                              NaN
# ...                           ...  ...                              ...
# 1540                          NaN  ...                              NaN
# 1541                          NaN  ...                              NaN
# 1542                          NaN  ...                              NaN
# 1543                          NaN  ...                              NaN
# 1544                          NaN  ...                              NaN
#
#       OUTPUT PROPERTY: Elongation plastic (%)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1540                                      NaN
# 1541                                      NaN
# 1542                                      NaN
# 1543                                      NaN
# 1544                                      NaN
#
#       OUTPUT PROPERTY: Exp. Young modulus (GPa)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 1540                                        NaN
# 1541                                        NaN
# 1542                                        NaN
# 1543                                        NaN
# 1544                                        NaN
#
#       OUTPUT PROPERTY: Calculated Young modulus (GPa)  \
# 0                                               192.0
# 1                                                 NaN
# 2                                                 NaN
# 3                                               162.0
# 4                                               207.0
# ...                                               ...
# 1540                                            119.0
# 1541                                            222.0
# 1542                                            222.0
# 1543                                            179.0
# 1544                                            179.0
#
#       INPUT PROPERTY: O content (wppm)  INPUT PROPERTY: N content (wppm)  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 1540                               NaN                               NaN
# 1541                               NaN                               NaN
# 1542                               NaN                               NaN
# 1543                               NaN                               NaN
# 1544                               NaN                               NaN
#
#       INPUT PROPERTY: C content (wppm)                REFERENCE: doi  \
# 0                                  NaN    10.1016/j.jmmm.2014.07.023
# 1                                  NaN    10.1016/j.jmmm.2014.07.023
# 2                                  NaN    10.1016/j.jmmm.2014.07.023
# 3                                  NaN    10.1016/j.jmmm.2014.07.023
# 4                                  NaN    10.1016/j.jmmm.2014.07.023
# ...                                ...                           ...
# 1540                               NaN  10.1016/j.matdes.2018.06.003
# 1541                               NaN  10.1016/j.matdes.2018.06.003
# 1542                               NaN  10.1016/j.matdes.2018.06.003
# 1543                               NaN  10.1016/j.matdes.2018.06.003
# 1544                               NaN  10.1016/j.matdes.2018.06.003
#
#       REFERENCE: year                                   REFERENCE: title
# 0                2014  Effects of Al and Si addition on the structure...
# 1                2014  Effects of Al and Si addition on the structure...
# 2                2014  Effects of Al and Si addition on the structure...
# 3                2014  Effects of Al and Si addition on the structure...
# 4                2014  Effects of Al and Si addition on the structure...
# ...               ...                                                ...
# 1540             2018  Phase equilibria, mechanical properties and de...
# 1541             2018  Phase equilibria, mechanical properties and de...
# 1542             2018  Phase equilibria, mechanical properties and de...
# 1543             2018  Phase equilibria, mechanical properties and de...
# 1544             2018  Phase equilibria, mechanical properties and de...
#
# [1545 rows x 23 columns]

# %%
mpea.describe()
# Out:
#        IDENTIFIER: Reference ID  INPUT PROPERTY: grain size ($\mu$m)  \
# count               1545.000000                           237.000000
# mean                 134.286084                            90.222121
# std                   80.288645                           182.997396
# min                    1.000000                             0.018200
# 25%                   62.000000                             3.000000
# 50%                  134.000000                            20.000000
# 75%                  210.000000                            92.000000
# max                  265.000000                          2000.000000
#
#        INPUT PROPERTY: Exp. Density (g/cm$^3$)  \
# count                               112.000000
# mean                                  7.639518
# std                                   2.484075
# min                                   1.460000
# 25%                                   6.505000
# 50%                                   7.781500
# 75%                                   8.680000
# max                                  13.600000
#
#        INPUT PROPERTY: Calculated Density (g/cm$^3$)  OUTPUT PROPERTY: HV  \
# count                                    1545.000000           530.000000
# mean                                        7.962071           478.256792
# std                                         1.760284           212.896712
# min                                         1.400000            94.700000
# 25%                                         6.900000           319.500000
# 50%                                         7.800000           479.150000
# 75%                                         8.500000           624.750000
# max                                        13.700000          1183.000000
#
#        INPUT PROPERTY: Test temperature ($^\circ$C)  \
# count                                   1364.000000
# mean                                     227.960264
# std                                      379.131987
# min                                     -268.800000
# 25%                                       25.000000
# 50%                                       25.000000
# 75%                                      300.000000
# max                                     1600.000000
#
#        OUTPUT PROPERTY: YS (MPa)  OUTPUT PROPERTY: UTS (MPa)  \
# count                1067.000000                  539.000000
# mean                  889.961471                 1180.121243
# std                   570.135437                  720.870146
# min                    24.000000                   80.000000
# 25%                   408.000000                  674.625000
# 50%                   822.000000                 1004.000000
# 75%                  1260.000000                 1456.000000
# max                  3416.000000                 4023.600000
#
#        OUTPUT PROPERTY: Elongation (%)  \
# count                       619.000000
# mean                         30.216688
# std                          22.010637
# min                           0.000000
# 25%                          10.700000
# 50%                          27.900000
# 75%                          50.000000
# max                         105.000000
#
#        OUTPUT PROPERTY: Elongation plastic (%)  \
# count                               149.000000
# mean                                 20.272349
# std                                  25.725757
# min                                   0.000000
# 25%                                   6.000000
# 50%                                  12.000000
# 75%                                  25.000000
# max                                 189.200000
#
#        OUTPUT PROPERTY: Exp. Young modulus (GPa)  \
# count                                 145.000000
# mean                                  124.972414
# std                                    56.943524
# min                                    16.600000
# 25%                                    83.500000
# 50%                                    99.200000
# 75%                                   182.000000
# max                                   240.000000
#
#        OUTPUT PROPERTY: Calculated Young modulus (GPa)  \
# count                                       729.000000
# mean                                        166.411523
# std                                          48.864223
# min                                          72.000000
# 25%                                         110.000000
# 50%                                         175.000000
# 75%                                         210.000000
# max                                         298.000000
#
#        INPUT PROPERTY: O content (wppm)  INPUT PROPERTY: N content (wppm)  \
# count                         57.000000                              45.0
# mean                         764.000000                               5.0
# std                         2084.998458                               0.0
# min                           80.000000                               5.0
# 25%                           90.000000                               5.0
# 50%                          100.000000                               5.0
# 75%                          200.000000                               5.0
# max                         7946.000000                               5.0
#
#        INPUT PROPERTY: C content (wppm)  REFERENCE: year
# count                          4.000000      1545.000000
# mean                       19911.750000      2016.209061
# std                        16142.818184         3.725479
# min                         1900.000000      2004.000000
# 25%                         8775.250000      2015.000000
# 50%                        20683.500000      2018.000000
# 75%                        31820.000000      2019.000000
# max                        36380.000000      2019.000000
